# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)



from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
from sklearn.model_selection import cross_validate,GridSearchCV,RandomizedSearchCV
from tpot import TPOTClassifier
from scipy.stats import randint
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics

# Data Uploading

# 1- Data Preperation

ps1=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/PS1.txt")

ps1

ps1.shape

np.isnan(ps1).sum()

ps2=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/PS2.txt")

ps3=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/PS3.txt")

ps4=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/PS4.txt")

ps5=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/PS5.txt")

ps6=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/PS6.txt")

ps2

ps1_arr=ps1.mean(axis=1)
ps1_arr

ps2_arr=ps2.mean(axis=1)
ps2_arr

ps3_arr=ps3.mean(axis=1)
ps3_arr

ps4_arr=ps4.mean(axis=1)
ps4_arr

ps5_arr=ps5.mean(axis=1)
ps5_arr

ps6_arr=ps6.mean(axis=1)
ps6_arr

df=pd.DataFrame({"PS1":ps1_arr,"PS2":ps2_arr,"PS3":ps3_arr,"PS4":ps4_arr,"PS5":ps5_arr,"PS6":ps6_arr})

df.head()

eps1=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/EPS1.txt")

esp1_arr=eps1.mean(axis=1)
esp1_arr

df["ESP1"]=esp1_arr

df.head()

a=[]
for i in ["FS1","FS2"]:
    FS=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive"+"/"+i+".txt")
    a.append(FS)
fs1,fs2=a

fs1_arr=fs1.mean(axis=1)
fs1_arr

fs2_arr=fs2.mean(axis=1)
fs2_arr

df["FS1"]=fs1_arr
df["FS2"]=fs2_arr

df.head()

a=[]
for i in ["TS1","TS2","TS3","TS4"]:
    TS=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive"+"/"+i+".txt")
    a.append(TS)
ts1,ts2,ts3,ts4=a

ts1_arr=ts1.mean(axis=1)
ts1_arr

ts2_arr=ts2.mean(axis=1)
ts2_arr

ts3_arr=ts3.mean(axis=1)
ts3_arr

ts4_arr=ts4.mean(axis=1)
ts4_arr

df["TS1"]=ts1_arr
df["TS2"]=ts2_arr
df["TS3"]=ts3_arr
df["TS4"]=ts4_arr

df.head()

vs1=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/VS1.txt")

vs1

vs1_arr=vs1.mean(axis=1)
vs1_arr

df["VS1"]=vs1_arr

df.head()

a=[]
for i in ["CE","CP"]:
    C=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive"+"/"+i+".txt")
    a.append(C)
ce,cp=a

ce_arr=ce.mean(axis=1)
ce_arr

cp_arr=cp.mean(axis=1)
cp_arr

df["CE"]=ce_arr
df["CP"]=cp_arr

df.head()

se=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/SE.txt")

se_arr=se.mean(axis=1)
se_arr

df["SE"]=se_arr

df.head()

target=np.genfromtxt("C:/Users/SystemDynamicsLab/Downloads/datasetforpredictive/profile.txt")

target

target.shape

df_temp=pd.DataFrame(target,columns=["Cooler_Condition","Valve_Condition","Internal_Pump_Leakage","Hydraulic_Accumulator","Stable_Flag"])
df_temp.head()

df_final=pd.concat([df,df_temp],axis=1)

df_final.head(20)



df_final.info()

df_final.describe()

# 2- Data Analysis

df_final.var()

df_final.corr()

fig=plt.gcf()
fig.set_size_inches((25,15))
sns.heatmap(df_final.corr(),annot=True)

# fig.savefig("corr.png")

df_final_corr=df_final.corr().sort_values(["Cooler_Condition","Valve_Condition","Internal_Pump_Leakage","Hydraulic_Accumulator","Stable_Flag"],ascending=False)
df_final_corr.head()

df_final_corr_target=df_final_corr[["Cooler_Condition","Valve_Condition","Internal_Pump_Leakage","Hydraulic_Accumulator","Stable_Flag"]]
df_final_corr_target.drop(["Cooler_Condition","Valve_Condition","Internal_Pump_Leakage","Hydraulic_Accumulator","Stable_Flag"],axis=0,inplace=True)

df_final_corr_target

# 3- Data Preprocessing

x=df_final.iloc[:,:-5]

x.head(2)

y=df_final.iloc[:,-5:]

y.head(2)

target_1=y.iloc[:,-5]
target_2=y.iloc[:,-4]
target_3=y.iloc[:,-3]
target_4=y.iloc[:,-2]
final_target=y.iloc[:,-1]
final_target=(final_target.astype(int))

target_1

x.head()

## data splitting target-1

### target incidence



# # Increase the epochs to 100
# history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=32)

# # Plot training & validation accuracy values
# plt.figure(figsize=(14, 6))

# plt.subplot(1, 2, 1)
# plt.plot(history.history['accuracy'], label='Training Accuracy')
# plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
# plt.title('Model Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend(loc='upper left')

# # Plot training & validation loss values
# plt.subplot(1, 2, 2)
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Model Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend(loc='upper left')

# plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PS1                    2205 non-null   float64
#  1   PS2                    2205 non-null   float64
#  2   PS3                    2205 non-null   float64
#  3   PS4                    2205 non-null   float64
#  4   PS5                    2205 non-null   float64
#  5   PS6                    2205 non-null   float64
#  6   ESP1                   2205 non-null   float64
#  7   FS1                    2205 non-null   float64
#  8   FS2                    2205 non-null   float64
#  9   TS1                    2205 non-null   float64
#  10  TS2                    2205 non-null   float64
#  11  TS3                    2205 non-null   float64
#  12  TS4                    2205 non-null   float64
#  13  VS1                    2205 non-null   float64
#  14  CE                     2205 non-null   float64
#  15  CP                     2205 non-null   float64
#  16  SE                     2205 non-null   float64
#  17  Cooler_Condition       2205 non-null   float64
#  18  Valve_Condition        2205 non-null   float64
#  19  Internal_Pump_Leakage  2205 non-null   float64
#  20  Hydraulic_Accumulator  2205 non-null   float64
#  21  Stable_Flag            2205 non-null   float64
# dtypes: float64(22)
# memory usage: 379.1 KB
# C:\Users\SystemDynamicsLab\AppData\Local\Temp\ipykernel_15924\1813840303.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_corr_target.drop(["Cooler_Condition","Valve_Condition","Internal_Pump_Leakage","Hydraulic_Accumulator","Stable_Flag"],axis=0,inplace=True)
#           PS1         PS2       PS3  PS4       PS5       PS6         ESP1  \
# 0  160.673492  109.466914  1.991475  0.0  9.842169  9.728098  2538.929167
# 1  160.603320  109.354890  1.976234  0.0  9.635142  9.529488  2531.498900
# 2  160.347720  109.158845  1.972224  0.0  9.530548  9.427949  2519.928000
# 3  160.188088  109.064807  1.946576  0.0  9.438827  9.337429  2511.541633
# 4  160.000472  108.931434  1.922707  0.0  9.358762  9.260636  2503.449500
#
#         FS1        FS2        TS1        TS2        TS3        TS4       VS1  \
# 0  6.709815  10.304592  35.621983  40.978767  38.471017  31.745250  0.576950
# 1  6.715315  10.403098  36.676967  41.532767  38.978967  34.493867  0.565850
# 2  6.718522  10.366250  37.880800  42.442450  39.631950  35.646150  0.576533
# 3  6.720565  10.302678  38.879050  43.403983  40.403383  36.579467  0.569267
# 4  6.690308  10.237750  39.803917  44.332750  41.310550  37.427900  0.577367
#
#           CE        CP         SE
# 0  39.601350  1.862750  59.157183
# 1  25.786433  1.255550  59.335617
# 2  22.218233  1.113217  59.543150
# 3  20.459817  1.062150  59.794900
# 4  19.787017  1.070467  59.455267

# %%
x2 = df.iloc[:, [0,1,2,4,5,16]]

x2

X_train,X_test,y_train,y_test=train_test_split(x2,target_2,test_size=0.2,random_state=1)

# %%
y_train = y_train.replace({100: 3, 90: 2, 80: 1,73: 0})
y_test = y_test.replace({100: 3, 90: 2, 80: 1,73: 0})

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Assuming your data is in a DataFrame called 'df'
# X is your feature matrix, y is your target column



# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define the MLP model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),  # Input layer with 64 neurons
    Dense(32, activation='relu'),  # Hidden layer with 32 neurons
    Dense(16, activation='relu'),  # Hidden layer with 16 neurons
    Dense(4, activation='softmax')  # Output layer with 3 neurons for 3 classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=32)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_train, y_train)
print(f'Train Accuracy: {test_accuracy:.4f}')

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/100
# 56/56 [==============================] - 1s 4ms/step - loss: 1.2427 - accuracy: 0.4909 - val_loss: 1.2377 - val_accuracy: 0.4649
# Epoch 2/100
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1585 - accuracy: 0.5221 - val_loss: 1.1958 - val_accuracy: 0.4649
# Epoch 3/100
# 56/56 [==============================] - 0s 2ms/step - loss: 1.1109 - accuracy: 0.5215 - val_loss: 1.1456 - val_accuracy: 0.4830
# Epoch 4/100
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0521 - accuracy: 0.5607 - val_loss: 1.0764 - val_accuracy: 0.5170
# Epoch 5/100
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0053 - accuracy: 0.5714 - val_loss: 1.0096 - val_accuracy: 0.5397
# Epoch 6/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.9418 - accuracy: 0.6003 - val_loss: 0.9351 - val_accuracy: 0.5896
# Epoch 7/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.8671 - accuracy: 0.6406 - val_loss: 0.8424 - val_accuracy: 0.6327
# Epoch 8/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.7774 - accuracy: 0.6808 - val_loss: 0.7497 - val_accuracy: 0.6871
# Epoch 9/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.6774 - accuracy: 0.7200 - val_loss: 0.6637 - val_accuracy: 0.7075
# Epoch 10/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5997 - accuracy: 0.7619 - val_loss: 0.5966 - val_accuracy: 0.8073
# Epoch 11/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.7800 - val_loss: 0.5374 - val_accuracy: 0.7800
# Epoch 12/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4864 - accuracy: 0.8158 - val_loss: 0.4548 - val_accuracy: 0.8707
# Epoch 13/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.8628 - val_loss: 0.4098 - val_accuracy: 0.9501
# Epoch 14/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8861 - val_loss: 0.3913 - val_accuracy: 0.8844
# Epoch 15/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3441 - accuracy: 0.9019 - val_loss: 0.3208 - val_accuracy: 0.9229
# Epoch 16/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.3156 - accuracy: 0.9087 - val_loss: 0.3054 - val_accuracy: 0.9365
# Epoch 17/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.9235 - val_loss: 0.3252 - val_accuracy: 0.9002
# Epoch 18/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.9286 - val_loss: 0.2448 - val_accuracy: 0.9524
# Epoch 19/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.9405 - val_loss: 0.2211 - val_accuracy: 0.9683
# Epoch 20/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.2010 - accuracy: 0.9444 - val_loss: 0.2233 - val_accuracy: 0.9342
# Epoch 21/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1944 - accuracy: 0.9439 - val_loss: 0.2013 - val_accuracy: 0.9683
# Epoch 22/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1878 - accuracy: 0.9433 - val_loss: 0.1999 - val_accuracy: 0.9569
# Epoch 23/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9603 - val_loss: 0.1787 - val_accuracy: 0.9751
# Epoch 24/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1735 - accuracy: 0.9388 - val_loss: 0.2086 - val_accuracy: 0.9615
# Epoch 25/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9580 - val_loss: 0.1656 - val_accuracy: 0.9705
# Epoch 26/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.9563 - val_loss: 0.1741 - val_accuracy: 0.9615
# Epoch 27/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1505 - accuracy: 0.9490 - val_loss: 0.2036 - val_accuracy: 0.9252
# Epoch 28/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1978 - accuracy: 0.9371 - val_loss: 0.1681 - val_accuracy: 0.9569
# Epoch 29/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1380 - accuracy: 0.9569 - val_loss: 0.1694 - val_accuracy: 0.9751
# Epoch 30/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1255 - accuracy: 0.9677 - val_loss: 0.1811 - val_accuracy: 0.9592
# Epoch 31/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9722 - val_loss: 0.1659 - val_accuracy: 0.9751
# Epoch 32/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1411 - accuracy: 0.9512 - val_loss: 0.1743 - val_accuracy: 0.9342
# Epoch 33/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9473 - val_loss: 0.1612 - val_accuracy: 0.9819
# Epoch 34/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.9694 - val_loss: 0.2353 - val_accuracy: 0.9569
# Epoch 35/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.9711 - val_loss: 0.1598 - val_accuracy: 0.9592
# Epoch 36/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1075 - accuracy: 0.9751 - val_loss: 0.1492 - val_accuracy: 0.9796
# Epoch 37/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9700 - val_loss: 0.1541 - val_accuracy: 0.9592
# Epoch 38/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1451 - accuracy: 0.9399 - val_loss: 0.1664 - val_accuracy: 0.9660
# Epoch 39/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9660 - val_loss: 0.1663 - val_accuracy: 0.9410
# Epoch 40/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9728 - val_loss: 0.1682 - val_accuracy: 0.9410
# Epoch 41/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 0.9694 - val_loss: 0.1451 - val_accuracy: 0.9773
# Epoch 42/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9649 - val_loss: 0.1712 - val_accuracy: 0.9433
# Epoch 43/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9768 - val_loss: 0.1493 - val_accuracy: 0.9819
# Epoch 44/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9711 - val_loss: 0.1369 - val_accuracy: 0.9841
# Epoch 45/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9734 - val_loss: 0.1637 - val_accuracy: 0.9524
# Epoch 46/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0983 - accuracy: 0.9649 - val_loss: 0.1408 - val_accuracy: 0.9683
# Epoch 47/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.9603 - val_loss: 0.1432 - val_accuracy: 0.9819
# Epoch 48/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9688 - val_loss: 0.1597 - val_accuracy: 0.9796
# Epoch 49/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9734 - val_loss: 0.1674 - val_accuracy: 0.9728
# Epoch 50/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.9546 - val_loss: 0.1424 - val_accuracy: 0.9796
# Epoch 51/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0859 - accuracy: 0.9785 - val_loss: 0.1276 - val_accuracy: 0.9819
# Epoch 52/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9745 - val_loss: 0.1277 - val_accuracy: 0.9819
# Epoch 53/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9677 - val_loss: 0.1308 - val_accuracy: 0.9637
# Epoch 54/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9807 - val_loss: 0.1227 - val_accuracy: 0.9864
# Epoch 55/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9768 - val_loss: 0.1322 - val_accuracy: 0.9887
# Epoch 56/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.9541 - val_loss: 0.1929 - val_accuracy: 0.9569
# Epoch 57/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0993 - accuracy: 0.9598 - val_loss: 0.1486 - val_accuracy: 0.9683
# Epoch 58/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 0.9830 - val_loss: 0.1279 - val_accuracy: 0.9751
# Epoch 59/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9796 - val_loss: 0.1374 - val_accuracy: 0.9773
# Epoch 60/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0786 - accuracy: 0.9796 - val_loss: 0.1253 - val_accuracy: 0.9819
# Epoch 61/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1035 - accuracy: 0.9677 - val_loss: 0.1404 - val_accuracy: 0.9637
# Epoch 62/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9717 - val_loss: 0.1622 - val_accuracy: 0.9524
# Epoch 63/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9768 - val_loss: 0.1194 - val_accuracy: 0.9864
# Epoch 64/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0844 - accuracy: 0.9751 - val_loss: 0.1376 - val_accuracy: 0.9796
# Epoch 65/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 0.9813 - val_loss: 0.1411 - val_accuracy: 0.9660
# Epoch 66/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9858 - val_loss: 0.1469 - val_accuracy: 0.9615
# Epoch 67/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9819 - val_loss: 0.1385 - val_accuracy: 0.9819
# Epoch 68/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0635 - accuracy: 0.9881 - val_loss: 0.1278 - val_accuracy: 0.9819
# Epoch 69/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9768 - val_loss: 0.1510 - val_accuracy: 0.9683
# Epoch 70/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9813 - val_loss: 0.1726 - val_accuracy: 0.9410
# Epoch 71/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.9637 - val_loss: 0.1204 - val_accuracy: 0.9887
# Epoch 72/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9841 - val_loss: 0.1566 - val_accuracy: 0.9569
# Epoch 73/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.9875 - val_loss: 0.2300 - val_accuracy: 0.9161
# Epoch 74/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1602 - accuracy: 0.9495 - val_loss: 0.1825 - val_accuracy: 0.9478
# Epoch 75/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0832 - accuracy: 0.9734 - val_loss: 0.1557 - val_accuracy: 0.9819
# Epoch 76/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.9654 - val_loss: 0.1345 - val_accuracy: 0.9683
# Epoch 77/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1370 - accuracy: 0.9541 - val_loss: 0.2764 - val_accuracy: 0.9342
# Epoch 78/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0755 - accuracy: 0.9841 - val_loss: 0.1394 - val_accuracy: 0.9637
# Epoch 79/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9807 - val_loss: 0.1341 - val_accuracy: 0.9887
# Epoch 80/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9756 - val_loss: 0.2545 - val_accuracy: 0.9184
# Epoch 81/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9711 - val_loss: 0.1383 - val_accuracy: 0.9683
# Epoch 82/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9802 - val_loss: 0.1600 - val_accuracy: 0.9388
# Epoch 83/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0859 - accuracy: 0.9671 - val_loss: 0.1431 - val_accuracy: 0.9592
# Epoch 84/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9694 - val_loss: 0.1104 - val_accuracy: 0.9887
# Epoch 85/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9909 - val_loss: 0.1271 - val_accuracy: 0.9796
# Epoch 86/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9722 - val_loss: 0.1479 - val_accuracy: 0.9592
# Epoch 87/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9853 - val_loss: 0.1356 - val_accuracy: 0.9683
# Epoch 88/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9796 - val_loss: 0.1179 - val_accuracy: 0.9864
# Epoch 89/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9836 - val_loss: 0.1133 - val_accuracy: 0.9887
# Epoch 90/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9870 - val_loss: 0.1138 - val_accuracy: 0.9909
# Epoch 91/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9762 - val_loss: 0.1482 - val_accuracy: 0.9819
# Epoch 92/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9813 - val_loss: 0.1409 - val_accuracy: 0.9660
# Epoch 93/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9847 - val_loss: 0.1245 - val_accuracy: 0.9773
# Epoch 94/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9864 - val_loss: 0.1114 - val_accuracy: 0.9864
# Epoch 95/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9586 - val_loss: 0.1491 - val_accuracy: 0.9569
# Epoch 96/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9756 - val_loss: 0.1338 - val_accuracy: 0.9887
# Epoch 97/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9898 - val_loss: 0.1097 - val_accuracy: 0.9841
# Epoch 98/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 0.9915 - val_loss: 0.1286 - val_accuracy: 0.9728
# Epoch 99/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 0.9870 - val_loss: 0.1133 - val_accuracy: 0.9909
# Epoch 100/100
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9909 - val_loss: 0.1223 - val_accuracy: 0.9728
# 56/56 [==============================] - 0s 1ms/step - loss: 0.0542 - accuracy: 0.9881
# Train Accuracy: 0.9881
# 14/14 [==============================] - 0s 514us/step - loss: 0.1223 - accuracy: 0.9728
# Test Accuracy: 0.9728

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict the labels for the test set
y_pred = np.argmax(model.predict(X_test), axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1, 2,3])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# 14/14 [==============================] - 0s 1ms/step

# %%
model.save('my_model3.h5')
# Out:
# C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
base_model = tf.keras.models.load_model('my_model4.h5')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict the labels for the test set
y_pred = np.argmax(base_model.predict(X_test), axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1, 2,3 ])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13436\4150747557.py in <module>
#       4
#       5 # Predict the labels for the test set
# ----> 6 y_pred = np.argmax(base_model.predict(X_test), axis=1)
#       7
#       8 # Generate the confusion matrix
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_32/sequential_9/dense_36/Relu defined at (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 87, in _run_code
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#
#   File "C:\ProgramData\Anaconda3\lib\asyncio\events.py", line 80, in _run
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#
#   File "C:\Users\SystemDynamicsLab\AppData\Local\Temp\ipykernel_13436\4150747557.py", line 6, in <module>
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py", line 2631, in predict
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py", line 2416, in predict_function
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py", line 2401, in step_function
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py", line 2389, in run_step
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py", line 2357, in predict_step
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py", line 589, in __call__
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer.py", line 1149, in __call__
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 96, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\sequential.py", line 398, in call
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\functional.py", line 515, in call
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\functional.py", line 672, in _run_internal_graph
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\training.py", line 589, in __call__
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer.py", line 1149, in __call__
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 96, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\sequential.py", line 398, in call
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\functional.py", line 515, in call
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\functional.py", line 672, in _run_internal_graph
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 65, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer.py", line 1149, in __call__
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\traceback_utils.py", line 96, in error_handler
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\core\dense.py", line 255, in call
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\activations.py", line 306, in relu
#
#   File "C:\Users\SystemDynamicsLab\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py", line 5397, in relu
#
# Matrix size-incompatible: In[0]: [32,9], In[1]: [2,64]
# 	 [[{{node sequential_32/sequential_9/dense_36/Relu}}]] [Op:__inference_predict_function_528951]
